# %%
import matplotlib.pyplot as plt
hits =[8370, 8430, 8435, 8504, 8538, 8577, 8581, 8587, 8603, 8606, 8606, 8606, 8606, 8606]
miss =[1440, 1380, 1375, 1306, 1272, 1233, 1229, 1223, 1207, 1204, 1204, 1204, 1204, 1204]



cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')

plt.show()

# %%
#for 50 mbps
import matplotlib.pyplot as plt

cache_sizes = range(70, 201, 10)

hits_32 = [0.5048419979612639, 0.5065953109072375, 0.5103363914373089, 0.5125586136595311, 0.5152293577981653, 0.5176248725790009, 0.5204791029561672, 0.5214882772680938, 0.5224057084607543, 0.527308868501529, 0.5284403669724771, 0.5311314984709481, 0.5357798165137615, 0.5387155963302753]
hits_64 = [0.5167074413863404, 0.5204587155963303, 0.5262385321100918, 0.5355963302752293, 0.5517635066258919, 0.5603771661569825, 0.5698572884811417, 0.5651070336391438, 0.5675433231396535, 0.5641386340468909, 0.5670846075433231, 0.5671967380224261, 0.5664627930682976, 0.5682670744138634]
hits_16 = [0.4674006116207952, 0.4727319062181448, 0.4791997961264015, 0.48334862385321103, 0.48685015290519884, 0.4836799184505606, 0.4825535168195718, 0.48535168195718664, 0.48540265035677876, 0.48413353720693175, 0.4866156982670744, 0.4850356778797146, 0.4884352701325179, 0.48858817533129467]
hits_8 = [0.334478423377506, 0.3842405708460754, 0.42537546721032965, 0.47093781855249744, 0.4787597689432552, 0.480295616717635, 0.481970778117567, 0.4823139653414882, 0.48462793068297666, 0.48160720353380904, 0.48280665987088006, 0.48301053346924916, 0.48221202854230366, 0.4822663948352022]
hits_4 = [0.23055725450220868, 0.2262317363234794, 0.39694529391777095, 0.39689092762487255, 0.4014067278287462, 0.4008698606863744, 0.3973870200475706, 0.43124702684335714, 0.4328916072035337, 0.43334012911994557, 0.48476384641522247, 0.48702684335711854, 0.49290859667006454, 0.4906455997281685]
hits_non_uniform = [0.8017227319062181, 0.8073190621814476, 0.8126095820591234, 0.8184607543323139, 0.8253822629969418, 0.8303261977573904, 0.8352497451580021, 0.8380632008154943, 0.8400000000000001, 0.8417125382262997, 0.8442711518858308, 0.8451681957186544, 0.8454128440366973, 0.8455045871559632]

plt.plot(cache_sizes, hits_64, label='Grid Size: 64 x 64')
plt.plot(cache_sizes, hits_32, label='Grid Size: 32 x 32')
plt.plot(cache_sizes, hits_16, label='Grid Size: 16 x 16')
plt.plot(cache_sizes, hits_8, label='Grid Size: 8 x 8')
plt.plot(cache_sizes, hits_4, label='Grid Size: 4 x 4')
plt.plot(cache_sizes, hits_non_uniform, label='Non-Uniform Grid')

plt.xlabel('Cache Size (MB)')
plt.ylabel('Hit Rates')
plt.title('Hit Rates for Different Grid Sizes')

plt.legend()
plt.grid(True)
plt.savefig('hit_rates.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#for 25 mbps
import matplotlib.pyplot as plt

cache_sizes = range(70, 201, 10)

hits_32 = [0.5126911314984709, 0.5164933741080531, 0.5246687054026504, 0.5338735983690113, 0.550203873598369, 0.5627624872579001, 0.5654332313965341, 0.5593476044852193, 0.5603363914373088, 0.5630377166156982, 0.5613965341488277, 0.5598165137614679, 0.5614780835881753, 0.5638328236493375]
hits_64 = [0.5090214067278287, 0.5124974515800205, 0.5127013251783893, 0.5164322120285423, 0.5172986748216106, 0.5214475025484201, 0.525045871559633, 0.525158002038736, 0.5266564729867482, 0.528032619775739, 0.5302854230377165, 0.5323037716615698, 0.5366666666666667, 0.539592252803262]
hits_16 = [0.4669317023445464, 0.47562691131498464, 0.4776656472986748, 0.4840672782874618, 0.4850050968399592, 0.48511722731906215, 0.4885830784913353, 0.49099898063200814, 0.4853618756371049, 0.4887155963302753, 0.48853211009174313, 0.48907237512742097, 0.48640163098878697, 0.4879001019367991]
hits_8 = [0.3378491335372069, 0.39723751274209995, 0.4291743119266055, 0.4765341488277269, 0.4866666666666667, 0.483730886850153, 0.4846177370030581, 0.4857390417940877, 0.48658511722731906, 0.48900101936799184, 0.489571865443425, 0.4863200815494394, 0.4875637104994904, 0.4873088685015291]
hits_4 = [0.2315290519877676, 0.22786952089704382, 0.39933741080530066, 0.3992966360856269, 0.40367991845056067, 0.4033231396534148, 0.3989500509683995, 0.43627930682976557, 0.43621814475025483, 0.436177370030581, 0.4763200815494394, 0.4803873598369012, 0.492986748216106, 0.4872986748216106]
hits_non_uniform = [0.8017227319062181, 0.8073190621814476, 0.8126095820591234, 0.8184607543323139, 0.8253822629969418, 0.8303261977573904, 0.8352497451580021, 0.8380632008154943, 0.8400000000000001, 0.8417125382262997, 0.8442711518858308, 0.8451681957186544, 0.8454128440366973, 0.8455045871559632]

plt.plot(cache_sizes, hits_64, label='Grid Size: 64 x 64')
plt.plot(cache_sizes, hits_32, label='Grid Size: 32 x 32')
plt.plot(cache_sizes, hits_16, label='Grid Size: 16 x 16')
plt.plot(cache_sizes, hits_8, label='Grid Size: 8 x 8')
plt.plot(cache_sizes, hits_4, label='Grid Size: 4 x 4')
plt.plot(cache_sizes, hits_non_uniform, label='Non-Uniform Grid')

plt.xlabel('Cache Size (MB)')
plt.ylabel('Hit Rates')
plt.title('Hit Rates for Different Grid Sizes')

plt.legend()
plt.grid(True)
plt.show()

# %%
#for 75 mbps
import matplotlib.pyplot as plt

cache_sizes = range(70, 201, 10)

hits_64 = [0.5070234454638125, 0.5105096839959226, 0.5136289500509683, 0.5165443425076452, 0.5177675840978593, 0.5187359836901122, 0.5210499490316004, 0.5220387359836901, 0.5228542303771662, 0.5256982670744138, 0.5271763506625893, 0.5291335372069317, 0.5349133537206933, 0.5378797145769623]
hits_32 = [0.5230173292558613, 0.522579001019368, 0.5351885830784913, 0.5460040774719672, 0.556493374108053, 0.5662079510703364, 0.5707339449541285, 0.5684709480122324, 0.5703567787971457, 0.5717940876656472, 0.5736697247706422, 0.5733537206931703, 0.5716921508664627, 0.5728848114169215]
hits_16 = [0.46351681957186547, 0.4714882772680937, 0.4760448521916413, 0.4808664627930684, 0.48005096839959227, 0.477940876656473, 0.48194699286442405, 0.48056065239551476, 0.48292558613659525, 0.48175331294597357, 0.48342507645259936, 0.48744138634046896, 0.48151885830784913, 0.48521916411824667]
hits_8 = [0.3335270132517839, 0.39363914373088693, 0.42790010193679906, 0.47080530071355753, 0.4806014271151885, 0.4821508664627931, 0.48644240570846076, 0.4795514780835881, 0.4876044852191641, 0.4856167176350662, 0.4833639143730887, 0.48595310907237516, 0.48613659531090725, 0.4912538226299694]
hits_4 = [0.23113149847094797, 0.22577981651376144, 0.3986544342507645, 0.39863404689092763, 0.40296636085626913, 0.40257900101936794, 0.3980020387359837, 0.42828746177370025, 0.43342507645259937, 0.4333843017329255, 0.4787461773700306, 0.4832517838939857, 0.49445463812436297, 0.49442405708460757]
hits_non_uniform = [0.8017227319062181, 0.8073190621814476, 0.8126095820591234, 0.8184607543323139, 0.8253822629969418, 0.8303261977573904, 0.8352497451580021, 0.8380632008154943, 0.8400000000000001, 0.8417125382262997, 0.8442711518858308, 0.8451681957186544, 0.8454128440366973, 0.8455045871559632]

plt.plot(cache_sizes, hits_64, label='Grid Size: 64 x 64')
plt.plot(cache_sizes, hits_32, label='Grid Size: 32 x 32')
plt.plot(cache_sizes, hits_16, label='Grid Size: 16 x 16')
plt.plot(cache_sizes, hits_8, label='Grid Size: 8 x 8')
plt.plot(cache_sizes, hits_4, label='Grid Size: 4 x 4')
plt.plot(cache_sizes, hits_non_uniform, label='Non-Uniform Grid')

plt.xlabel('Cache Size (MB)')
plt.ylabel('Hit Rates')
plt.title('Hit Rates for Different Grid Sizes')

plt.legend()
plt.grid(True)
plt.show()

# %%
#for 5 mbps
import matplotlib.pyplot as plt

cache_sizes = range(70, 201, 10)

hits_64 = [0.508165137614679, 0.5115494393476044, 0.516829765545362, 0.5165035677879716, 0.519500509683996, 0.5237920489296637, 0.5244852191641182, 0.5271049949031601, 0.528756371049949, 0.5303669724770642, 0.5313557594291539, 0.5348216106014271, 0.5389194699286443, 0.5423343527013251]
hits_32 = [0.5188786952089703, 0.5213251783893985, 0.5279816513761467, 0.5356167176350662, 0.5532008154943935, 0.5578899082568808, 0.5706829765545363, 0.5702548419979613, 0.5667380224260958, 0.5629561671763507, 0.568369011213048, 0.567716615698267, 0.5711926605504587, 0.572150866462793]
hits_16 = [0.4692558613659531, 0.469571865443425, 0.4731600407747196, 0.4759734964322121, 0.4804994903160041, 0.4768399592252803, 0.47742099898063206, 0.4811009174311927, 0.4818552497451579, 0.48046890927624875, 0.4838735983690112, 0.48124362895005096, 0.4841896024464831, 0.4780530071355759]
hits_8 = [0.33126401630988794, 0.39351681957186535, 0.42827726809378197, 0.4723139653414883, 0.475474006116208, 0.4824159021406727, 0.47546381243628943, 0.48278287461773706, 0.48291539245667686, 0.4837512742099898, 0.48647298674821615, 0.4884097859327216, 0.4852191641182467, 0.48784913353720694]
hits_4 = [0.23223241590214067, 0.22867482161060143, 0.39978593272171253, 0.3997247706422019, 0.40411824668705404, 0.403710499490316, 0.39923547400611625, 0.4368705402650357, 0.43671763506625894, 0.436697247706422, 0.4936085626911315, 0.4988175331294597, 0.4939347604485219, 0.4939347604485219]
hits_non_uniform = [0.8017227319062181, 0.8073190621814476, 0.8126095820591234, 0.8184607543323139, 0.8253822629969418, 0.8303261977573904, 0.8352497451580021, 0.8380632008154943, 0.8400000000000001, 0.8417125382262997, 0.8442711518858308, 0.8451681957186544, 0.8454128440366973, 0.8455045871559632]

plt.plot(cache_sizes, hits_64, label='Grid Size: 64 x 64')
plt.plot(cache_sizes, hits_32, label='Grid Size: 32 x 32')
plt.plot(cache_sizes, hits_16, label='Grid Size: 16 x 16')
plt.plot(cache_sizes, hits_8, label='Grid Size: 8 x 8')
plt.plot(cache_sizes, hits_4, label='Grid Size: 4 x 4')
plt.plot(cache_sizes, hits_non_uniform, label='Non-Uniform Grid')

plt.xlabel('Cache Size (MB)')
plt.ylabel('Hit Rates')
plt.title('Hit Rates for Different Grid Sizes')

plt.legend()
plt.grid(True)
plt.show()
