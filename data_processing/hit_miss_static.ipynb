# %%
import matplotlib.pyplot as plt


# hits =[7589, 7621, 7702, 7756, 7792, 7810, 7819, 7827, 7840, 7840, 7840, 7840, 7840, 7840]
# miss = [2221, 2189, 2108, 2054, 2018, 2000, 1991, 1983, 1970, 1970, 1970, 1970, 1970, 1970]

hits =[0.507512742099898, 0.5127115188583079, 0.5145565749235473, 0.5199490316004077, 0.5213659531090724, 0.5231192660550459, 0.5242915392456677, 0.5278083588175331, 0.5289296636085628, 0.5314067278287462, 0.5315698267074414, 0.5350764525993884, 0.5390214067278287, 0.5430581039755351]
miss =[4802, 4844, 4812, 4727, 4700, 4680, 4620, 4613, 4621, 4564, 4598, 4552, 4540, 4505]

cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')
plt.suptitle('Grid Size: 64 x 64')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')
plt.suptitle('Grid Size: 64 x 64')

plt.show()

# %%
# hits =[8432, 8451, 8535, 8506, 8544, 8546, 8551, 8604, 8668, 8679, 8735, 8774, 8787, 8786]
# miss = [1378, 1359, 1275, 1304, 1266, 1264, 1259, 1206, 1142, 1131, 1075, 1036, 1023, 1024]

hits =[0.5200611620795107, 0.5176656472986748, 0.5273802242609582, 0.5375433231396534, 0.5602650356778798, 0.567624872579001, 0.5757900101936799, 0.5713149847094801, 0.5703465851172274, 0.5686544342507646, 0.5694903160040775, 0.570703363914373, 0.5732619775739043, 0.5742813455657492]
miss =[4618, 4612, 4500, 4544, 4374, 4122, 4147, 4126, 4229, 4103, 4208, 4158, 4159, 4224]


cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')
plt.suptitle('Grid Size: 32 x 32')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')
plt.suptitle('Grid Size: 32 x 32')

plt.show()

# %%
# hits = [4444, 4330, 4535, 4689, 4367, 4398, 4534, 4591, 4542, 4779, 4412, 4796, 4708, 4509]
# miss = [5366, 5480, 5275, 5121, 5443, 5412, 5276, 5219, 5268, 5031, 5398, 5014, 5102, 5301]


hits=[0.45609582059123344, 0.4667074413863405, 0.46675840978593264, 0.4757696228338431, 0.4772171253822631, 0.47828746177370024, 0.47650356778797154, 0.4775637104994902, 0.4790010193679918, 0.48070336391437307, 0.4798165137614679, 0.48309887869520896, 0.4812028542303771, 0.48057084607543316]
miss=[5294, 5176, 5075, 4947, 5006, 5033, 4992, 5037, 4996, 4955, 5005, 4901, 5006, 4913]

cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')
plt.suptitle('Grid Size: 16 x 16')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')
plt.suptitle('Grid Size: 16 x 16')

plt.show()

# %%
hits = [3569, 3887, 4170, 4706, 4655, 4653, 4680, 4680, 4644, 4636, 4639, 4654, 4776, 4629]
miss = [6241, 5923, 5640, 5104, 5155, 5157, 5130, 5130, 5166, 5174, 5171, 5156, 5034, 5181]

cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')
plt.suptitle('Grid Size: 8 x 8')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')
plt.suptitle('Grid Size: 8 x 8')

plt.show()

# %%
hits = [2176, 2316, 3815, 3815, 3859, 3848, 3864, 4058, 4053, 4148, 4652, 4652, 4652, 4652]
miss = [7634, 7494, 5995, 5995, 5951, 5962, 5946, 5752, 5757, 5662, 5158, 5158, 5158, 5158]

cache_sizes = range(70, 201, 10)

# Plotting hits
plt.figure(1)
plt.plot(cache_sizes, hits)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Hits')
plt.title('Cache Hits')
plt.suptitle('Grid Size: 4 x 4')

# Plotting misses
plt.figure(2)
plt.plot(cache_sizes, miss)
plt.xlabel('Cache Size (MB)')
plt.ylabel('Misses')
plt.title('Cache Misses')
plt.suptitle('Grid Size: 4 x 4')

plt.show()
