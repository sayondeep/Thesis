# %%
import numpy as np

for i in range(0,50):
    print(np.random.exponential(scale=10))
# Out:
# 10.599621374704988
# 4.363099038566066
# 5.55716615111208
# 21.04650230388929
# 12.322650280113368
# 4.833400252738718
# 2.4027891026538137
# 1.075866223655034
# 38.56857959246436
# 0.8020008375319991
# 4.952585389185312
# 16.750402822019023
# 1.8425122270367202
# 4.7383704761853265
# 0.28598788371481004
# 20.327091901404838
# 12.438673934531703
# 7.446678996176338
# 10.983283292351382
# 7.6389484306597275
# 0.6755433326061621
# 14.240561559362877
# 0.3313025210426346
# 4.543049037907372
# 22.59372746200668
# 1.8870767238347883
# 12.995795513905598
# 19.718022633139075
# 5.180114441770521
# 29.427946315749722
# 0.2123726719645277
# 1.636542931574928
# 3.865694430125195
# 1.7001814011755845
# 7.17992864968088
# 3.3309120281341587
# 6.009630700628752
# 10.893335748197652
# 4.202742472659525
# 1.7457058730743948
# 10.89377054455145
# 12.970228915979458
# 5.536142310674059
# 20.95945910943861
# 31.038575418652137
# 3.152348778761586
# 13.466355226056223
# 3.639360694647947
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of CSV files
csv_files =['/home/sayon/Thesis/pcd_cache/time_to_voxelize.csv','/home/sayon/Thesis/voxelization/64_time_to_voxelize.csv','/home/sayon/Thesis/voxelization/32_time_to_voxelize.csv','/home/sayon/Thesis/voxelization/16_time_to_voxelize.csv','/home/sayon/Thesis/voxelization/8_time_to_voxelize.csv','/home/sayon/Thesis/voxelization/4_time_to_voxelize.csv']
# Initialize total sizes for each file
total_times = []

# Calculate total size for each file
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    total_time = 0
    for index, row in df.iterrows():
        if row['Time'] == row['Valid_From']:
            # file_size = row['Size']
            file_time = row['time_to_voxelize']
            total_time += file_time
    total_times.append(total_time)

# Plot the graph
plt.bar(csv_files, total_times)
plt.xlabel('CSV File')
plt.ylabel('Total time (s)')
plt.title('Total time for voxelization')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List of CSV files
csv_files = ['/home/sayon/Thesis/pcd_cache/time_to_voxelize.csv',
             '/home/sayon/Thesis/voxelization/64_time_to_voxelize.csv',
             '/home/sayon/Thesis/voxelization/32_time_to_voxelize.csv',
             '/home/sayon/Thesis/voxelization/16_time_to_voxelize.csv',
             '/home/sayon/Thesis/voxelization/8_time_to_voxelize.csv',
             '/home/sayon/Thesis/voxelization/4_time_to_voxelize.csv']

# Specify x labels manually
x_labels = ['Non-uniform', '64x64', '32x32', '16x16', '8x8', '4x4']

# Initialize total times for each file
total_times = []

# Calculate total time for each file
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    total_time = 0
    for index, row in df.iterrows():
        if row['Time'] == row['Valid_From']:
            file_time = row['time_to_voxelize']
            total_time += file_time
    total_times.append(round(total_time, 2))  # Restrict to 2 decimal places

# Plot the graph
plt.bar(x_labels, total_times)
# plt.xlabel('CSV File')
plt.ylabel('Total time (s)')
plt.title('Total time for voxelization')
plt.xticks(rotation=45)

# Add labels on top of the bars
for i, v in enumerate(total_times):
    plt.text(i, v, str(v), ha='center', va='bottom')
plt.savefig('time.eps', format='eps')
plt.show()
